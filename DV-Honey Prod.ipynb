# %% [markdown]
# # Data Visualization on Honey Production dataset using seaborn and matplotlib libraries.

# %% [markdown]
# ## Domain: Food and Agriculture

# %% [markdown]
# ### Q1. Import required libraries and read the dataset.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/MILAN/Downloads/honeyproduction (1).csv')
df.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %% [markdown]
# ### Q2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features

# %%
df.shape
# Out:
# (626, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
df.describe(include = 'all').T
# Out:
#              count unique  top freq            mean             std       min  \
# state          626     44   AL   15             NaN             NaN       NaN
# numcol       626.0    NaN  NaN  NaN    60284.345048    91077.087231    2000.0
# yieldpercol  626.0    NaN  NaN  NaN       62.009585       19.458754      19.0
# totalprod    626.0    NaN  NaN  NaN  4169086.261981  6883846.751268   84000.0
# stocks       626.0    NaN  NaN  NaN   1318859.42492  2272963.665923    8000.0
# priceperlb   626.0    NaN  NaN  NaN        1.409569        0.638599      0.49
# prodvalue    626.0    NaN  NaN  NaN  4715741.214058   7976109.76856  162000.0
# year         626.0    NaN  NaN  NaN     2004.864217        4.317306    1998.0
#
#                   25%        50%        75%         max
# state             NaN        NaN        NaN         NaN
# numcol         9000.0    26000.0    63750.0    510000.0
# yieldpercol      48.0       60.0       74.0       136.0
# ...

# %% [markdown]
# ### Q3.  Display the percentage distribution of the data in each year using the pie chart.

# %%
x = df['year'].value_counts()
plt.pie(x,labels = ['2001','2002','2003','1998','1999','2000','2004','2005','2006','2007','2008','2009','2010','2011','2012'],autopct = '%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1f40b57eb10>,
# ...
#  [Text(1.0732912380245243, 0.24092720556172983, '2001'),
#   Text(0.8673402443051562, 0.6765507376455014, '2002'),
#   Text(0.49495764388020447, 0.9823527527138899, '2003'),
#   Text(0.03311719478341548, 1.099501364896687, '1998'),
#   Text(-0.4298607422968863, 1.0125313537031682, '1999'),
#   Text(-0.8140028043229933, 0.7398644703959657, '2000'),
#   Text(-1.0454777286429804, 0.3420180096303625, '2004'),
#   Text(-1.0950031934867976, -0.10472824954955927, '2005'),
#   Text(-0.9616948061219724, -0.5339879210974927, '2006'),
#   Text(-0.6678112103027948, -0.8740870593904915, '2007'),
#   Text(-0.26242246376439426, -1.0682389482282628, '2008'),
#   Text(0.18134071660305257, -1.0849495585057822, '2009'),
#   Text(0.590900327226214, -0.9278129139454534, '2010'),
#   Text(0.9064867637158847, -0.6231225779956158, '2011'),
#   Text(1.0779110893191872, -0.21933463821914498, '2012')],
#  [Text(0.5854315843770133, 0.13141483939730716, '7.0%'),
# ...

# %% [raw]
# From the above mentioned chart, we can see that higest amount of data is on 2001,2002,2003 holding 7% each and the lowest data is 2009,2010,2011,2012 of totally holding an 6.4% each. So we can see here that majority of the share is starts from 6.5% to 7.0%.

# %%
df['year'].value_counts()
# Out:
# 2001    44
# 2002    44
# 2003    44
# 1998    43
# 1999    43
# 2000    43
# 2004    41
# 2005    41
# 2006    41
# 2007    41
# 2008    41
# 2009    40
# 2010    40
# 2011    40
# 2012    40
# Name: year, dtype: int64

# %% [markdown]
# ### Q4.. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.displot(df['priceperlb'],kde = True)
plt.show()

# %% [raw]
# Inference:
#     As per the above mentioned chart, the mean and median for the price per lb is relies on 1.4 to 1.3 so slightly similar to each other so both can be considered as an centre of the date and for the symmetry skewness, its been like 'Positive Skewness' it says that more data to the left and there is tailing data on the right side of the chart, for the kurtosis, the value of the kurtosis its been like '2' so since its been positive and slightly sharp peakness.

# %% [markdown]
# ###  Q5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
ncl = df['numcol']
pdl = df['prodvalue']
plt.xlabel('No.of. Honey producing colonies')
plt.ylabel('Value of Production')
plt.scatter(x = ncl,y = pdl)

# %% [raw]
# Inference:
#     From the overview, we can see that, linearly(diagonally) decreasing, 'If The No.of.Prod. colonies increasing the value of the production is also increasing'. So we can see that {comparatively} is more data  from 0 to 100K and after 100K there is an decreasing in no.of.honey prod. colonies.

# %% [markdown]
# ### Q6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
sns.boxplot(data = df,x='year',y='prodvalue')
# Out:
# <Axes: xlabel='year', ylabel='prodvalue'>

# %% [raw]
# From the above mentioned chart, every plot has an outlayers but the highest no.of. outlayers is on 2010...

# %% [markdown]
# ### Q7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences

# %%
sns.pairplot(df,hue = 'year',kind = 'scatter',palette = "husl")

# %% [raw]
# Inference:
#     from the above mentioned chart we can see that 2010 has done an great impact on everything. Compartively to 2010, 2012 has very less impact like numcol, yieldpercol, totalcol and prodvalue

# %% [markdown]
# ### Q8. Display the correlation values using a plot and add your inferences.

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
# C:\Users\MILAN\AppData\Local\Temp\ipykernel_4788\868109210.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
#                numcol  yieldpercol  totalprod    stocks  priceperlb  \
# numcol       1.000000     0.243515   0.953594  0.825929   -0.232701
# yieldpercol  0.243515     1.000000   0.396252  0.367812   -0.358646
# totalprod    0.953594     0.396252   1.000000  0.878830   -0.264499
# stocks       0.825929     0.367812   0.878830  1.000000   -0.305867
# priceperlb  -0.232701    -0.358646  -0.264499 -0.305867    1.000000
# prodvalue    0.912796     0.278977   0.907236  0.728560   -0.089567
# year         0.008709    -0.232092  -0.055556 -0.119602    0.693984
#
#              prodvalue      year
# numcol        0.912796  0.008709
# yieldpercol   0.278977 -0.232092
# ...

# %%
sns.heatmap(correlation_matrix,annot = True)
plt.show()

# %% [raw]
# Inference:
#     From the above mentioned chart we can see that the highest correlation is for 'Total Production' vs 'No.of.Honey producing colonies'and the nest higest correlation is on 'Value of the product' vs 'No.of.Honey producing colonies' and 'Value of the product' and 'Total Production'...

# %% [markdown]
# ## Conclusion:

# %% [raw]
# Inference:
#     As per the above mentioned chart basis, we can see that upto 100K on no.of.Honey production there is low or normal value but when the numcol increases there is an increase in value of the production also and as per the pair plot we can see that 2010 has an greatest impact of all others coloumn and same like heatmap we can see that the higest correlation is on 'Total production' vs 'No.of.Honey Producing colonies' and the negative point is on outlayers.
#         As per the Conclusion we can say that 2010 has been high on Honey production but for 2012 there is low honey production comparatively to the 2010...
