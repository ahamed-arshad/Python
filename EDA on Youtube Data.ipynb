# %% [markdown]
# #  EXPLORATORY DATA ANALYSIS ON YOUTUBE DATA

# %% [markdown]
# ## Questions:

# %% [raw]
# 1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/MILAN/Downloads/youtube_dislike_dataset.csv')

# %%
df.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
df.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [raw]
# 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
df.shape
# Out:
# (37422, 12)

# %% [raw]
# Inference:
#     As per the above mentioned data, the overall data has four interget type of coloumn and eight object type of column and each column has thirtyseven thousand four hundred twenty twenty records.
# and we can see in the shape option.

# %% [raw]
# 3. Check for the Percentage of the missing values and drop or impute them.

# %%
df.isnull().sum()
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
df.isnull().sum()*100 / len(df)
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %% [raw]
# 4. Check the statistical summary of both numerical and categorical columns and write your inferences

# %%
df.describe(include='all').T
# Out:
#                  count unique  \
# video_id         37422  37422
# title            37422  37113
# channel_id       37422  10961
# channel_title    37422  10883
# published_at     37422  36772
# view_count     37422.0    NaN
# likes          37422.0    NaN
# dislikes       37422.0    NaN
# comment_count  37422.0    NaN
# tags             37422  28799
# description      37422  35630
# comments         37264  37264
#
#                                                              top  freq  \
# video_id                                             --0bCF-iK2E     1
# title                                                        www    21
# channel_id                              UCNAf1k0yIjyGu3k9BwAg3lg   533
# channel_title                                Sky Sports Football   533
# published_at                                 2020-10-16 04:00:10     6
# view_count                                                   NaN   NaN
# ...

# %% [raw]
# Inference:
#     we can see, most of the count max limit is 37422 except comments all other coloumns has an count of 37422.

# %% [raw]
# 5. Convert datatype of column published_at from object to pandas datetime

# %%
df['published_at'] = pd.to_datetime(df['published_at'])
df['published_at']
# Out:
# 0       2021-07-01 10:00:00
# 1       2021-06-10 16:00:00
# 2       2021-09-20 01:03:32
# 3       2021-03-03 10:00:17
# 4       2021-12-07 13:00:00
#                 ...
# 37417   2021-02-12 05:03:49
# 37418   2021-01-16 05:39:05
# 37419   2021-06-02 09:00:10
# 37420   2020-10-20 20:59:30
# 37421   2021-05-23 21:00:31
# Name: published_at, Length: 37422, dtype: datetime64[ns]

# %% [raw]
# 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
df['published_month'] = df['published_at'].dt.month
df['published_month']
# Out:
# 0         7
# 1         6
# 2         9
# 3         3
# 4        12
#          ..
# 37417     2
# 37418     1
# 37419     6
# 37420    10
# 37421     5
# Name: published_month, Length: 37422, dtype: int64

# %% [raw]
# 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.....

# %%
df['published_month'] = df['published_month'].replace(1,'Jan')
df['published_month'] = df['published_month'].replace(2,'Feb')
df['published_month'] = df['published_month'].replace(3,'Mar')
df['published_month'] = df['published_month'].replace(4,'Apr')
df['published_month'] = df['published_month'].replace(5,'May')
df['published_month'] = df['published_month'].replace(6,'June')
df['published_month'] = df['published_month'].replace(7,'July')
df['published_month'] = df['published_month'].replace(8,'Aug')
df['published_month'] = df['published_month'].replace(9,'Sep')
df['published_month'] = df['published_month'].replace(10,'Oct')
df['published_month'] = df['published_month'].replace(11,'Nov')
df['published_month'] = df['published_month'].replace(12,'Dec')
df['published_month']
# Out:
# 0        July
# 1        June
# 2         Sep
# 3         Mar
# 4         Dec
#          ...
# 37417     Feb
# 37418     Jan
# 37419    June
# 37420     Oct
# 37421     May
# Name: published_month, Length: 37422, dtype: object

# %% [raw]
# 9. Find the count of unique video_id, channel_id and channel_title.

# %%
df['video_id'].nunique()
# Out:
# 37422

# %%
df['channel_id'].nunique()
# Out:
# 10961

# %%
df['channel_title'].nunique()
# Out:
# 10883

# %% [raw]
# 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10
# having lowest number of videos.

# %%
df.sort_values(['channel_title'], ascending=False).groupby('video_id').head(10).T
# Out:
#                                                              23682  \
# video_id                                               cOKCrLpvOgg
# title            BTS ft. Sakshma Srivastav | Indian Interview |...
# channel_id                                UCotI-SqRXnkAZX4bMqlRNjw
# channel_title                                                 zoom
# published_at                                   2021-06-05 09:00:13
# view_count                                                15087469
# likes                                                      1154281
# dislikes                                                     23248
# comment_count                                               126194
# tags             BTS RM Jin Suga J-Hope Jimin Jungkook BTS Indi...
# description      The biggest K-Pop group in the world BTS joins...
# comments         The moment you all have been waiting for! BTS ...
# published_month                                               June
#
# ...

# %%
df.sort_values(['channel_title'], ascending=False).groupby('video_id').tail(10).T
# Out:
#                                                              23682  \
# video_id                                               cOKCrLpvOgg
# title            BTS ft. Sakshma Srivastav | Indian Interview |...
# channel_id                                UCotI-SqRXnkAZX4bMqlRNjw
# channel_title                                                 zoom
# published_at                                   2021-06-05 09:00:13
# view_count                                                15087469
# likes                                                      1154281
# dislikes                                                     23248
# comment_count                                               126194
# tags             BTS RM Jin Suga J-Hope Jimin Jungkook BTS Indi...
# description      The biggest K-Pop group in the world BTS joins...
# comments         The moment you all have been waiting for! BTS ...
# published_month                                               June
#
# ...

# %% [raw]
# 11.  Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
df.sort_values(['likes'], ascending=False).groupby('title').head(1).T
# Out:
#                                                              26143  \
# video_id                                               gdZLi9oWNZg
# title                                BTS () 'Dynamite' Official MV
# channel_id                                UC3IZKseVpdzPSBaWxBxundA
# channel_title                                          HYBE LABELS
# published_at                                   2020-08-21 03:58:10
# view_count                                              1322796924
# likes                                                     31837675
# dislikes                                                   1814333
# comment_count                                             16071029
# tags                                         BIGHIT   BTS BANGTAN
# description      BTS () 'Dynamite' Official MV\n\n\nCredits:\nD...
# comments         Armys, we will strive for the mv to reach 100 ...
# published_month                                                Aug
#
# ...

# %%
df.sort_values(['likes'], ascending=True).groupby('title').head(1).T
# Out:
#                                                              18654  \
# video_id                                               Uh-lqtF2yO8
# title            Kim Kardashian's Must-See Moments on "Saturday...
# channel_id                                UCjDsbbzHgTrGc4Ff26TJtsA
# channel_title                                              E! News
# published_at                                   2021-10-10 08:36:34
# view_count                                                  403616
# likes                                                            0
# dislikes                                                         0
# comment_count                                                    0
# tags             E! NEWS NOW WOCHIT CELEBRITIES TOP STORIES TOP...
# description      Kim Kardashian takes her @Saturday Night Live ...
# comments                                                       NaN
# published_month                                                Oct
#
# ...

# %% [raw]
# Inference:
#     The most liked video from the datset is 'BTS () 'Dynamite' Official MV'
#     The Lease liked video from the dataset is 'Kim Kardashian's Must-See Moments on "Saturday..'
#     as per the above mentioned data the likes are slightly affecting the views count and vice versa

# %% [raw]
# 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
df.sort_values(['dislikes'], ascending=False).groupby('title').head(1).T
# Out:
#                                                              13591  \
# video_id                                               M0O7lLe4SmA
# title                          Cuties | Official Trailer | Netflix
# channel_id                                UCWOA1ZGywLbqmigxE4Qlvuw
# channel_title                                              Netflix
# published_at                                   2020-08-18 14:00:00
# view_count                                                17996395
# likes                                                        94569
# dislikes                                                   2397733
# comment_count                                               205009
# tags             Cuties Mignonnes Netflix NetflixFilm Dance Mai...
# description      Eleven-year-old Amy starts to rebel against he...
# comments         I love how the mom is the bad guy for not lett...
# published_month                                                Aug
#
# ...

# %%
df.sort_values(['dislikes'], ascending=True).groupby('title').head(1).T
# Out:
#                                                              18654  \
# video_id                                               Uh-lqtF2yO8
# title            Kim Kardashian's Must-See Moments on "Saturday...
# channel_id                                UCjDsbbzHgTrGc4Ff26TJtsA
# channel_title                                              E! News
# published_at                                   2021-10-10 08:36:34
# view_count                                                  403616
# likes                                                            0
# dislikes                                                         0
# comment_count                                                    0
# tags             E! NEWS NOW WOCHIT CELEBRITIES TOP STORIES TOP...
# description      Kim Kardashian takes her @Saturday Night Live ...
# comments                                                       NaN
# published_month                                                Oct
#
# ...

# %% [raw]
# Inference:
#     The maximum no. of. disliked video title is Cuties | Official Trailer | Netflix
#     the mininum no. of. disliked video title is Kim Kardashian's Must-See Moments on "Saturday..

# %% [raw]
# 13. Does the number of views have any effect on how many people disliked the video? Support your
# answer with a metric and a plot.

# %%
sns.scatterplot(x=df["view_count"], y=df["dislikes"], data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 sns.scatterplot(x=df["view_count"], y=df["dislikes"], data=df)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %% [raw]
# Inference:
#         From the above mentioned chart we can see that the lowest count of view has lowest dislikes but subsequently very few of the cases only has higher view count and higher dislikes and some of them got few view count and more dislikes. So hence it makes sure that, the lower the view count there will be an lower of dislikes that sure but for high view count it may not be predictable...

# %% [markdown]
# # Thank You
